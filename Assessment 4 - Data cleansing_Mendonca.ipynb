# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Company Sales Dataset.csv')
df.head(7306)
# Out:
#             Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 0     30/12/2004         10472          26        Computers       Laptop
# 1     31/12/2004          3706          74   Home Appliance   Headphones
# 2     01/01/2005         19407          77      Electronics   Headphones
# 3     02/01/2005          2850          71      Electronics   Headphones
# 4     03/01/2005         14739           8   Home Appliance   Headphones
# ...          ...           ...         ...              ...          ...
# 7301  26/12/2024          4747          81    Mobile Phones   Smartphone
# 7302  27/12/2024          9130          23        Computers       Tablet
# 7303  28/12/2024          5523          81    Mobile Phones       Laptop
# 7304  29/12/2024          7478          54      Electronics       Laptop
# 7305  30/12/2024          5457          85        Computers   Headphones
#
#       Revenue Revenue.1  Customer_Rating Sales_Channel
# ...

# %%
# Drops any duplicate rows in the dataset and saves the updated dataset
df = df.drop_duplicates()
df
# Out:
#             Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 0     30/12/2004         10472          26        Computers       Laptop
# 1     31/12/2004          3706          74   Home Appliance   Headphones
# 2     01/01/2005         19407          77      Electronics   Headphones
# 3     02/01/2005          2850          71      Electronics   Headphones
# 4     03/01/2005         14739           8   Home Appliance   Headphones
# ...          ...           ...         ...              ...          ...
# 7301  26/12/2024          4747          81    Mobile Phones   Smartphone
# 7302  27/12/2024          9130          23        Computers       Tablet
# 7303  28/12/2024          5523          81    Mobile Phones       Laptop
# 7304  29/12/2024          7478          54      Electronics       Laptop
# 7305  30/12/2024          5457          85        Computers   Headphones
#
#       Revenue Revenue.1  Customer_Rating Sales_Channel
# ...

# %%
# Drops the 'Revenue' column from the dataset
df = df.drop(columns = "Revenue")
df
# Out:
#             Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 0     30/12/2004         10472          26        Computers       Laptop
# 1     31/12/2004          3706          74   Home Appliance   Headphones
# 2     01/01/2005         19407          77      Electronics   Headphones
# 3     02/01/2005          2850          71      Electronics   Headphones
# 4     03/01/2005         14739           8   Home Appliance   Headphones
# ...          ...           ...         ...              ...          ...
# 7301  26/12/2024          4747          81    Mobile Phones   Smartphone
# 7302  27/12/2024          9130          23        Computers       Tablet
# 7303  28/12/2024          5523          81    Mobile Phones       Laptop
# 7304  29/12/2024          7478          54      Electronics       Laptop
# 7305  30/12/2024          5457          85        Computers   Headphones
#
#      Revenue.1  Customer_Rating Sales_Channel
# ...

# %%
# Removes the '$' sign from the revenue column and converts it to integer, then to UK currency format
df['Revenue.1'] = df['Revenue.1'].str.lstrip("$")
df['Revenue.1'] = df['Revenue.1'].astype(int)
df['Revenue.1'] = df['Revenue.1'].map("£{:,.0f}".format)
df
# Out:
#             Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 0     30/12/2004         10472          26        Computers       Laptop
# 1     31/12/2004          3706          74   Home Appliance   Headphones
# 2     01/01/2005         19407          77      Electronics   Headphones
# 3     02/01/2005          2850          71      Electronics   Headphones
# 4     03/01/2005         14739           8   Home Appliance   Headphones
# ...          ...           ...         ...              ...          ...
# 7301  26/12/2024          4747          81    Mobile Phones   Smartphone
# 7302  27/12/2024          9130          23        Computers       Tablet
# 7303  28/12/2024          5523          81    Mobile Phones       Laptop
# 7304  29/12/2024          7478          54      Electronics       Laptop
# 7305  30/12/2024          5457          85        Computers   Headphones
#
#      Revenue.1  Customer_Rating Sales_Channel
# ...

# %%
# Converts the date column to date format
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#            Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 0    2004-12-30         10472          26        Computers       Laptop
# 1    2004-12-31          3706          74   Home Appliance   Headphones
# 2    2005-01-01         19407          77      Electronics   Headphones
# 3    2005-02-01          2850          71      Electronics   Headphones
# 4    2005-03-01         14739           8   Home Appliance   Headphones
# ...         ...           ...         ...              ...          ...
# 7301 2024-12-26          4747          81    Mobile Phones   Smartphone
# 7302 2024-12-27          9130          23        Computers       Tablet
# 7303 2024-12-28          5523          81    Mobile Phones       Laptop
# 7304 2024-12-29          7478          54      Electronics       Laptop
# 7305 2024-12-30          5457          85        Computers   Headphones
#
#      Revenue.1  Customer_Rating Sales_Channel
# 0       £3,527              3.0           NaN
# ...

# %%
#Converts all data in the columns to Title case
df['Product_Category'] = df['Product_Category'].str.title()
df['Product_Name'] = df['Product_Name'].str.title()
df['Sales_Channel'] = df['Sales_Channel'].str.title()
df
# Out:
#            Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 0    2004-12-30         10472          26        Computers       Laptop
# 1    2004-12-31          3706          74   Home Appliance   Headphones
# 2    2005-01-01         19407          77      Electronics   Headphones
# 3    2005-02-01          2850          71      Electronics   Headphones
# 4    2005-03-01         14739           8   Home Appliance   Headphones
# ...         ...           ...         ...              ...          ...
# 7301 2024-12-26          4747          81    Mobile Phones   Smartphone
# 7302 2024-12-27          9130          23        Computers       Tablet
# 7303 2024-12-28          5523          81    Mobile Phones       Laptop
# 7304 2024-12-29          7478          54      Electronics       Laptop
# 7305 2024-12-30          5457          85        Computers   Headphones
#
#      Revenue.1  Customer_Rating Sales_Channel
# 0       £3,527              3.0           NaN
# ...

# %%
# Replaces all NaN rows with a blank value
df['Sales_Channel'] = df['Sales_Channel'].fillna('')
df
# Out:
#            Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 0    2004-12-30         10472          26        Computers       Laptop
# 1    2004-12-31          3706          74   Home Appliance   Headphones
# 2    2005-01-01         19407          77      Electronics   Headphones
# 3    2005-02-01          2850          71      Electronics   Headphones
# 4    2005-03-01         14739           8   Home Appliance   Headphones
# ...         ...           ...         ...              ...          ...
# 7301 2024-12-26          4747          81    Mobile Phones   Smartphone
# 7302 2024-12-27          9130          23        Computers       Tablet
# 7303 2024-12-28          5523          81    Mobile Phones       Laptop
# 7304 2024-12-29          7478          54      Electronics       Laptop
# 7305 2024-12-30          5457          85        Computers   Headphones
#
#      Revenue.1  Customer_Rating Sales_Channel
# 0       £3,527              3.0
# ...

# %%
# Removes blank cells from the Sales_Channel column
for x in df.index:
    if df.loc[x, "Sales_Channel"] == '':
        df.drop(x,inplace=True)
        
df
# Out:
#            Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 1    2004-12-31          3706          74   Home Appliance   Headphones
# 2    2005-01-01         19407          77      Electronics   Headphones
# 3    2005-02-01          2850          71      Electronics   Headphones
# 4    2005-03-01         14739           8   Home Appliance   Headphones
# 5    2005-04-01         14408          53   Home Appliance       Tablet
# ...         ...           ...         ...              ...          ...
# 7300 2024-12-25          6399          97   Home Appliance   Smartphone
# 7302 2024-12-27          9130          23        Computers       Tablet
# 7303 2024-12-28          5523          81    Mobile Phones       Laptop
# 7304 2024-12-29          7478          54      Electronics       Laptop
# 7305 2024-12-30          5457          85        Computers   Headphones
#
#      Revenue.1  Customer_Rating Sales_Channel
# 1       £3,528              NaN        Online
# ...

# %%
# Uses Numpy to replace the NaN values in the customer_Rating column to the mean of the data in that column,
# before converting the two string columns to integer data type.
mean = df['Customer_Rating'].mean()
df['Customer_Rating'].replace(np.nan, mean, inplace=True)
df['Customer_Rating'] = df['Customer_Rating'].astype(int)
df
# Out:
#            Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 1    2004-12-31          3706          74   Home Appliance   Headphones
# 2    2005-01-01         19407          77      Electronics   Headphones
# 3    2005-02-01          2850          71      Electronics   Headphones
# 4    2005-03-01         14739           8   Home Appliance   Headphones
# 5    2005-04-01         14408          53   Home Appliance       Tablet
# ...         ...           ...         ...              ...          ...
# 7300 2024-12-25          6399          97   Home Appliance   Smartphone
# 7302 2024-12-27          9130          23        Computers       Tablet
# 7303 2024-12-28          5523          81    Mobile Phones       Laptop
# 7304 2024-12-29          7478          54      Electronics       Laptop
# 7305 2024-12-30          5457          85        Computers   Headphones
#
#      Revenue.1  Customer_Rating Sales_Channel
# 1       £3,528                3        Online
# ...

# %%
# Removes outliers in the sales_amount column, where the Sales_Amount are not 
# suitable for the units_Sold.
for x in df.index:
    if (df.loc[x, 'Sales_Amount'] > 9000 and df.loc[x, 'Units_Sold'] <= 10) or (df.loc[x, 'Sales_Amount'] < 10000 and df.loc[x, 'Units_Sold'] >= 40):
        df.drop(x,inplace=True)

df
# Out:
#            Date  Sales_Amount  Units_Sold Product_Category Product_Name  \
# 2    2005-01-01         19407          77      Electronics   Headphones
# 5    2005-04-01         14408          53   Home Appliance       Tablet
# 14   2005-01-13          7483          29      Electronics   Headphones
# 15   2005-01-14         13848          84   Home Appliance       Tablet
# 17   2005-01-16         16247          95      Electronics       Tablet
# ...         ...           ...         ...              ...          ...
# 7295 2024-12-20         14165          75   Home Appliance   Smartphone
# 7296 2024-12-21         17954          53    Mobile Phones       Tablet
# 7298 2024-12-23         14880          71   Home Appliance       Laptop
# 7299 2024-12-24         17599          94    Mobile Phones       Tablet
# 7302 2024-12-27          9130          23        Computers       Tablet
#
#      Revenue.1  Customer_Rating Sales_Channel
# 2       £3,529                3        Online
# ...

# %%
# Converts Sales_Amount to integer then to currency format
df['Sales_Amount'] = df['Sales_Amount'].astype(int)
df['Sales_Amount'] = df['Sales_Amount'].map("£{:,.0f}".format)
df
# Out:
#            Date Sales_Amount  Units_Sold Product_Category Product_Name  \
# 2    2005-01-01      £19,407          77      Electronics   Headphones
# 5    2005-04-01      £14,408          53   Home Appliance       Tablet
# 14   2005-01-13       £7,483          29      Electronics   Headphones
# 15   2005-01-14      £13,848          84   Home Appliance       Tablet
# 17   2005-01-16      £16,247          95      Electronics       Tablet
# ...         ...          ...         ...              ...          ...
# 7295 2024-12-20      £14,165          75   Home Appliance   Smartphone
# 7296 2024-12-21      £17,954          53    Mobile Phones       Tablet
# 7298 2024-12-23      £14,880          71   Home Appliance       Laptop
# 7299 2024-12-24      £17,599          94    Mobile Phones       Tablet
# 7302 2024-12-27       £9,130          23        Computers       Tablet
#
#      Revenue.1  Customer_Rating Sales_Channel
# 2       £3,529                3        Online
# ...

# %%
# Goes through the dataset and standardises the categories that each product belongs too.
for x in df.index:
    if df.loc[x, 'Product_Name'] == "Laptop":
        df.loc[x, 'Product_Category'] = "Computers"
    elif df.loc[x, 'Product_Name'] == "Smartphone":
        df.loc[x, 'Product_Category'] = "Mobile Phones"
    elif df.loc[x, 'Product_Name'] == "Headphones" or df.loc[x, 'Product_Name'] == "Tablet" :
        df.loc[x, 'Product_Category'] = "Electronics"
df
# Out:
#            Date Sales_Amount  Units_Sold Product_Category Product_Name  \
# 2    2005-01-01      £19,407          77      Electronics   Headphones
# 5    2005-04-01      £14,408          53      Electronics       Tablet
# 14   2005-01-13       £7,483          29      Electronics   Headphones
# 15   2005-01-14      £13,848          84      Electronics       Tablet
# 17   2005-01-16      £16,247          95      Electronics       Tablet
# ...         ...          ...         ...              ...          ...
# 7295 2024-12-20      £14,165          75    Mobile Phones   Smartphone
# 7296 2024-12-21      £17,954          53      Electronics       Tablet
# 7298 2024-12-23      £14,880          71        Computers       Laptop
# 7299 2024-12-24      £17,599          94      Electronics       Tablet
# 7302 2024-12-27       £9,130          23      Electronics       Tablet
#
#      Revenue.1  Customer_Rating Sales_Channel
# 2       £3,529                3        Online
# ...

# %%
# Creates a new CSV file with all the changes
df.to_csv('CleanedData.csv')
